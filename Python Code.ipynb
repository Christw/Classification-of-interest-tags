# %%
import pandas as pd
from google.colab import files

# %%
df =pd.read_excel('YC.xlsx')
df
# Out:
#     segment   f0_
# 0        男女  6825
# 1      網路迷因  5845
# 2      感情經營  5811
# 3      學業生活  2866
# 4        星座  2714
# ..      ...   ...
# 261    個人衛生     1
# 262    包裝咖啡     1
# 263    頸部飾品     1
# 264      襪子     1
# 265   枕頭/棉被     1
#
# [266 rows x 2 columns]

# %%
df.isnull().value_counts()
# Out:
# segment  f0_
# False    False    265
# True     False      1
# dtype: int64

# %%
df = df.dropna()

# %%
new_third_tags_to_first = {
"3C 賣場":"3C產品",
"3C品牌":"3C產品",
"二手車":"交通",
"口腔保健品牌":"保養美體",
"大眾服飾品牌":"服飾配件",
"大眾運輸":"交通",
"女同性戀":"兩性",
"女性服飾品牌":"服飾配件",
"小說":"閱讀",
"工作鞋":"服飾配件",
"工具服務":"應用與遊戲",
"中式餐點":"食品餐飲",
"中式餐廳":"食品餐飲",
"中國明星":"影音娛樂",
"內衣":"服飾配件",
"內衣服飾品牌":"服飾配件",
"內褲":"服飾配件",
"公益":"生活",
"化妝工具":"美妝",
"化妝品":"美妝",
"升學考":"校園",
"戶外運動":"運動與健身",
"手作工具":"興趣",
"手沖咖啡":"食品餐飲",
"手部飾品":"服飾配件",
"手搖杯":"食品餐飲",
"手機周邊":"3C產品",
"手機周邊":"3C產品",
"手機周邊":"3C產品",
"手機周邊":"3C產品",
"手機周邊":"3C產品",
"手機品牌":"3C產品",
"手錶品牌":"服飾配件",
"文具興趣":"日常用品",
"日文":"海外",
"日本明星":"影音娛樂",
"日韓餐點":"食品餐飲",
"止汗調節":"保養美體",
"水上運動":"運動與健身",
"水果":"食品餐飲",
"水果加工品":"食品餐飲",
"牙齒保養":"保養美體",
"牙齒疾病":"生活",
"牙齒矯正":"保養美體",
"包包":"服飾配件",
"包裝咖啡":"食品餐飲",
"卡片":"生活",
"卡片/禮盒":"興趣",
"去痘保養":"保養美體",
"古著":"服飾配件",
"台灣明星":"影音娛樂",
"台灣甜點":"食品餐飲",
"台灣景點":"旅遊",
"台灣縣市":"旅遊",
"外套":"服飾配件",
"外送平台":"應用與遊戲",
"孕婦產品":"日常用品",
"布料":"興趣",
"平板":"3C產品",
"平板電腦":"3C產品",
"平板電腦":"3C產品",
"平板電腦":"3C產品",
"平板電腦":"3C產品",
"平面設計":"工作",
"生理用品":"日常用品",
"生理用藥":"日常用品",
"皮夾":"服飾配件",
"交友軟體":"應用與遊戲",
"交通執照":"交通",
"交通號誌/標線":"交通",
"休閒鞋":"服飾配件",
"冰品":"食品餐飲",
"同性戀":"兩性",
"成人文學":"兩性",
"成人玩具":"兩性",
"成藥":"日常用品",
"有線耳機":"3C產品",
"百貨公司":"服飾配件",
"百貨公司":"興趣",
"羽球":"運動與健身",
"自由工作者":"工作",
"自行車":"交通",
"跨性別":"兩性",
"路由器":"3C產品",
"遊戲":"應用與遊戲",
"遊戲-女性向遊戲":"應用與遊戲",
"遊戲-小品遊戲":"應用與遊戲",
"遊戲-卡牌遊戲":"應用與遊戲",
"遊戲-男性向遊戲":"應用與遊戲",
"遊戲-武俠":"應用與遊戲",
"遊戲-動作遊戲":"應用與遊戲",
"遊戲-動作遊戲'":"應用與遊戲",
"遊戲-博弈遊戲":"應用與遊戲",
"遊戲-策略遊戲":"應用與遊戲",
"遊戲-運動遊戲":"應用與遊戲",
"遊戲-DotA遊戲":"應用與遊戲",
"遊戲-FPS":"應用與遊戲",
"遊戲-MMORPG":"應用與遊戲",
"遊戲-RPG":"應用與遊戲",
"遊戲平台":"應用與遊戲",
"運動/能量飲料":"食品餐飲",
"運動用品品牌":"服飾配件",
"運動衣物":"服飾配件",
"運動賽事":"運動與健身",
"運動與健身":"運動與健身",
"零食(甜)":"食品餐飲",
"零食(鹹)":"食品餐飲",
"電子支付":"應用與遊戲",
"電子書":"閱讀",
"電子產品":"日常用品",
"電信服務":"3C產品",
"電信服務":"3C產品",
"電信服務":"3C產品",
"電信服務":"3C產品",
"電信服務":"3C產品",
"電信服務":"3C產品",
"電腦硬體":"3C產品",
"電腦硬體":"3C產品",
"電腦硬體":"3C產品",
"電腦硬體":"3C產品",
"電腦硬體":"3C產品",
"電腦硬體":"3C產品",
"電影":"影音娛樂",
"靴子":"服飾配件",
"鼠類":"興趣",
"慢性疾病":"生活",
"漫畫家":"閱讀",
"管樂器":"興趣",
"精品包":"服飾配件",
"維修":"3C產品",
"維修":"3C產品",
"網球":"運動與健身",
"網路小說":"閱讀",
"網路迷因":"興趣",
"網路購物":"興趣",
"網路購物":"應用與遊戲",
"舞蹈":"運動與健身",
"輔助程式":"應用與遊戲",
"輕小說":"閱讀",
"劇場":"影音娛樂",
"劇場":"興趣",
"廚房家電":"日常用品",
"影音平台":"應用與遊戲",
"影廳":"影音娛樂",
"撞球":"運動與健身",
"樂譜":"興趣",
"模型玩具":"興趣",
"模型玩偶":"興趣",
"歐美明星":"影音娛樂",
"歐美電影戲劇":"影音娛樂",
"熱敷眼罩":"保養美體",
"線材":"3C產品",
"線材":"3C產品",
"衛生棉":"日常用品",
"課程APP":"應用與遊戲",
"髮飾":"保養美體",
"髮膠":"保養美體",
"學業生活":"校園",
"整形":"保養美體",
"機車":"交通",
"機車品牌":"交通",
"機車配件":"交通",
"螢幕":"3C產品",
"螢幕":"3C產品",
"褲子(女)":"服飾配件",
"褲子(男女皆可)":"服飾配件",
"貓":"興趣",
"辦公文具":"日常用品",
"頸部飾品":"服飾配件",
"餐具":"日常用品",
"餐飲業":"工作",
"餐點相關":"食品餐飲",
"優惠禮/券":"理財",
"嬰兒產品":"日常用品",
"戲曲":"興趣",
"戲劇":"影音娛樂",
"環保家居":"日常用品",
"環境香氛":"日常用品",
"臉部保養":"保養美體",
"臉部保養品牌":"保養美體",
"避孕用品":"日常用品",
"避孕藥品":"日常用品",
"鍵盤":"3C產品",
"鍵盤樂器":"興趣",
"隱形眼鏡":"日常用品",
"韓文":"海外",
"韓國明星":"影音娛樂",
"黏膠":"興趣",
"禮品":"生活",
"職場生活":"工作",
"職業考試":"工作",
"豐胸用品":"日常用品",
"轉學考":"校園",
"醫事人員":"工作",
"醫美品牌":"美妝",
"醫療機構":"美妝",
"雙眼皮貼":"美妝",
"顏料":"興趣",
"簽證":"旅遊",
"繪畫":"興趣",
"繪圖板":"3C產品",
"藥妝店":"興趣",
"鏡頭":"興趣",
"礦物材料":"興趣",
"籃球":"運動與健身",
"警察":"工作",
"攝影配件":"興趣",
"攝影類型":"興趣",
"襪子":"服飾配件",
"護理師":"工作",
"護照":"旅遊",
"護髮":"保養美體",
"襯衫":"服飾配件",
"體育團體":"運動與健身",
"AirPods":"3C產品",
"BDSM":"兩性",
"iPad":"3C產品",
"iPad":"3C產品",
"iPhone":"3C產品",
"MacBook":"3C產品",
"nsfw":"兩性",
"suggested_segment":"兩性",
"YouTuber":"影音娛樂"
}

# %%
df["new_seg"] = df.segment.map(new_third_tags_to_first)
df.isnull().value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# segment  f0_    new_seg
# False    False  False      265
# dtype: int64

# %%
df[df.new_seg.isnull()]['segment'].unique()
# Out:
# array([], dtype=object)

# %%
df
# Out:
#     segment   f0_ new_seg
# 0        男女  6825      兩性
# 1      網路迷因  5845      興趣
# 2      感情經營  5811      兩性
# 3      學業生活  2866      校園
# 4        星座  2714      興趣
# ..      ...   ...     ...
# 261    個人衛生     1    日常用品
# 262    包裝咖啡     1    食品餐飲
# 263    頸部飾品     1    服飾配件
# 264      襪子     1    服飾配件
# 265   枕頭/棉被     1    日常用品
#
# [265 rows x 3 columns]

# %%
new_df=df[['new_seg','f0_']]
new_df
# Out:
#     new_seg   f0_
# 0        兩性  6825
# 1        興趣  5845
# 2        兩性  5811
# 3        校園  2866
# 4        興趣  2714
# ..      ...   ...
# 261    日常用品     1
# 262    食品餐飲     1
# 263    服飾配件     1
# 264    服飾配件     1
# 265    日常用品     1
#
# [265 rows x 2 columns]

# %%
group_count = new_df.groupby(['new_seg']).sum().sort_values(by=['f0_'],ascending=False)
group_count.columns=['counts']
group_count
# Out:
#          counts
# new_seg
# 興趣        17409
# 兩性        14823
# 校園         7755
# 影音娛樂       7657
# 工作         7130
# 應用與遊戲      7000
# 生活         5758
# 日常用品       5656
# 服飾配件       5444
# 運動與健身      4731
# 理財         3822
# 3C產品       3746
# 食品餐飲       3317
# 美妝         2565
# 交通         2419
# 閱讀         1826
# 旅遊         1653
# 保養美體       1602
# 海外          910

# %%
group_count.to_excel("YC2.xlsx") 
files.download("YC2.xlsx")
